# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\vsr07\anaconda3\lib\site-packages (0.0.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: beautifulsoup4 in c:\users\vsr07\anaconda3\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\vsr07\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import requests

url = "https://books.toscrape.com"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)

print(response.status_code)
# Out:
# 200

# %%
books_data = []

# %%
print(response.text[:1000])
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->
#     <head>
#         <title>
#     All products | Books to Scrape - Sandbox
# </title>
#
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#         <meta name="created" content="24th Jun 2016 09:29" />
#         <meta name="description" content="" />
#         <meta name="viewport" content="width=device-width" />
#         <meta name="robots" content="NOARCHIVE,NOCACHE" />
#
#         <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#         <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#
#
#             <link rel="shortcut icon" href="static/oscar/favicon.

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
print(soup.title)
# Out:
# <title>
#     All products | Books to Scrape - Sandbox
# </title>

# %%
print(soup.title.text)
# Out:
#     All products | Books to Scrape - Sandbox

# %%
#we ask the python how many books on the page
books = soup.find_all("article", class_="product_pod")
print(len(books))
# Out:
# 20

# %%
first_book = books[0] #first book

# %%
title = first_book.h3.a["title"] #book title
print(title)
# Out:
# A Light in the Attic

# %%
price = first_book.find("p", class_="price_color").text #book price
print(price)
# Out:
# Â£51.77

# %%
rating = first_book.find("p", class_="star-rating")["class"][1] #book rating
print(rating)
# Out:
# Three

# %%
availability = first_book.find("p", class_="instock availability").text.strip()
print(availability)
# Out:
# In stock

# %%
print(len(books))
# Out:
# 20

# %%
#single book code in single line 
for book in books:
    title = book.h3.a["title"]
    price = book.find("p", class_="price_color").text
    rating = book.find("p", class_="star-rating")["class"][1]
    availability = book.find("p", class_="instock availability").text.strip()

    books_data.append([title, price, rating, availability])

# %%
len(books_data)
# Out:
# 20

# %%
books_data[:2]
# Out:
# [['A Light in the Attic', 'Â£51.77', 'Three', 'In stock'],
#  ['Tipping the Velvet', 'Â£53.74', 'One', 'In stock']]

# %%
books_data = []

for page in range(1, 21):   # 1 to 20 pages
    url = f"https://books.toscrape.com/catalogue/page-{page}.html"

    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    books = soup.find_all("article", class_="product_pod")
    print(f"Page {page} → Books found: {len(books)}")

    for book in books:
        title = book.h3.a["title"]
        price_text = book.find("p", class_="price_color").text
        price = float(price_text.replace("£", "").replace("Â", "")) #this is error hapining
        rating = book.find("p", class_="star-rating")["class"][1]
        availability = book.find("p", class_="instock availability").text.strip()
        book_url = book.h3.a["href"]

        books_data.append([
            title,
            float(price),
            rating,
            availability,
            page,
            book_url
        ])
# Out:
# Page 1 → Books found: 20
# Page 2 → Books found: 20
# Page 3 → Books found: 20
# Page 4 → Books found: 20
# Page 5 → Books found: 20
# Page 6 → Books found: 20
# Page 7 → Books found: 20
# Page 8 → Books found: 20
# Page 9 → Books found: 20
# Page 10 → Books found: 20
# Page 11 → Books found: 20
# Page 12 → Books found: 20
# Page 13 → Books found: 20
# Page 14 → Books found: 20
# Page 15 → Books found: 20
# Page 16 → Books found: 20
# Page 17 → Books found: 20
# Page 18 → Books found: 20
# Page 19 → Books found: 20
# Page 20 → Books found: 20

# %%
len(books_data)
# Out:
# 400

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    books_data,
    columns=[
        "title",
        "price_gbp",
        "rating_text",
        "availability_text",
        "page_number",
        "book_url"
    ]
)

# %%
df.shape
# Out:
# (400, 6)

# %%
df.head()
# Out:
#                                    title  price_gbp rating_text  \
# 0                   A Light in the Attic      51.77       Three
# 1                     Tipping the Velvet      53.74         One
# 2                             Soumission      50.10         One
# 3                          Sharp Objects      47.82        Four
# 4  Sapiens: A Brief History of Humankind      54.23        Five
#
#   availability_text  page_number  \
# 0          In stock            1
# 1          In stock            1
# 2          In stock            1
# 3          In stock            1
# 4          In stock            1
#
#                                             book_url
# 0               a-light-in-the-attic_1000/index.html
# 1                  tipping-the-velvet_999/index.html
# 2                          soumission_998/index.html
# 3                       sharp-objects_997/index.html
# 4  sapiens-a-brief-history-of-humankind_996/index...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              400 non-null    object
#  1   price_gbp          400 non-null    float64
#  2   rating_text        400 non-null    object
#  3   availability_text  400 non-null    object
#  4   page_number        400 non-null    int64
#  5   book_url           400 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
#we want 8-columns so we add 2 in very smart way but first rating 
#column was one,two,three value we convert it onto the 1,2,3- values
rating_map = {
    "One": 1,
    "Two": 2,
    "Three": 3,
    "Four": 4,
    "Five": 5
}

df["rating_numeric"] = df["rating_text"].map(rating_map)

# %%
#we add one column with REF of "availability_text" -Yes=In stock,No=Not in stock
df["is_in_stock"] = df["availability_text"].apply(
    lambda x: "Yes" if "In stock" in x else "No"
)

# %%
df.shape #here is we have 8-columns now
# Out:
# (400, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              400 non-null    object
#  1   price_gbp          400 non-null    float64
#  2   rating_text        400 non-null    object
#  3   availability_text  400 non-null    object
#  4   page_number        400 non-null    int64
#  5   book_url           400 non-null    object
#  6   rating_numeric     400 non-null    int64
#  7   is_in_stock        400 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 25.1+ KB

# %%
df["page_number"].value_counts().sort_index()
# Out:
# page_number
# 1     20
# 2     20
# 3     20
# 4     20
# 5     20
# 6     20
# 7     20
# 8     20
# 9     20
# 10    20
# 11    20
# 12    20
# 13    20
# 14    20
# 15    20
# 16    20
# 17    20
# 18    20
# 19    20
# 20    20
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['title', 'price_gbp', 'rating_text', 'availability_text', 'page_number',
#        'book_url', 'rating_numeric', 'is_in_stock'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# title                0
# price_gbp            0
# rating_text          0
# availability_text    0
# page_number          0
# book_url             0
# rating_numeric       0
# is_in_stock          0
# dtype: int64

# %%
df.duplicated().sum() #if found used this df = df.drop_duplicates()
# Out:
# np.int64(0)

# %%
df['price_gbp'].describe()
# Out:
# count    400.00000
# mean      34.95980
# std       14.52635
# min       10.16000
# 25%       21.93000
# 50%       36.80500
# 75%       47.68250
# max       59.90000
# Name: price_gbp, dtype: float64

# %%
df['rating_numeric'].value_counts().sort_index()
# Out:
# rating_numeric
# 1    88
# 2    82
# 3    80
# 4    73
# 5    77
# Name: count, dtype: int64

# %%
df['page_number'].value_counts().sort_index()
# Out:
# page_number
# 1     20
# 2     20
# 3     20
# 4     20
# 5     20
# 6     20
# 7     20
# 8     20
# 9     20
# 10    20
# 11    20
# 12    20
# 13    20
# 14    20
# 15    20
# 16    20
# 17    20
# 18    20
# 19    20
# 20    20
# Name: count, dtype: int64

# %%
print(df.shape)
df.isna().sum()
# Out:
# (400, 8)
# title                0
# price_gbp            0
# rating_text          0
# availability_text    0
# page_number          0
# book_url             0
# rating_numeric       0
# is_in_stock          0
# dtype: int64

# %% [markdown]
# ### Lets Start EDA Q&A

# %%
#1.What is the overall price distribution of books?(most books cheap or expensive-price spred)

# %%
df['price_gbp'].describe() #1st way # insights = mean → average price
                                    # min / max → price range
# Out:
# count    400.00000
# mean      34.95980
# std       14.52635
# min       10.16000
# 25%       21.93000
# 50%       36.80500
# 75%       47.68250
# max       59.90000
# Name: price_gbp, dtype: float64

# %%
avg_price = df['price_gbp'].mean() #2nd way
avg_price
# Out:
# np.float64(34.9598)

# %%
#2.Which rating is most common?

# %%
df['rating_numeric'].value_counts().sort_index()
# Out:
# rating_numeric
# 1    88
# 2    82
# 3    80
# 4    73
# 5    77
# Name: count, dtype: int64

# %%
print(df['rating_numeric'].value_counts().sort_index())
df.groupby('rating_numeric')['price_gbp'].mean() # insights= Most books are rated 3–4 stars.
# Out:
# rating_numeric
# 1    88
# 2    82
# 3    80
# 4    73
# 5    77
# Name: count, dtype: int64
# rating_numeric
# 1    35.502045
# 2    33.605488
# 3    34.727625
# 4    36.652603
# 5    34.418701
# Name: price_gbp, dtype: float64

# %%
#3.Do higher-rated books cost more

# %%
df.groupby('rating_numeric')['price_gbp'].mean() # insights= Compare average price by rating
                                                 # Look for upward / flat trend
# Out:
# rating_numeric
# 1    35.502045
# 2    33.605488
# 3    34.727625
# 4    36.652603
# 5    34.418701
# Name: price_gbp, dtype: float64

# %%
#4.Are books evenly distributed across pages

# %%
df['page_number'].value_counts().sort_index() # insights= Exactly 20 books per page → no missing data.
# Out:
# page_number
# 1     20
# 2     20
# 3     20
# 4     20
# 5     20
# 6     20
# 7     20
# 8     20
# 9     20
# 10    20
# 11    20
# 12    20
# 13    20
# 14    20
# 15    20
# 16    20
# 17    20
# 18    20
# 19    20
# 20    20
# Name: count, dtype: int64

# %%
#5.How many books are in stock

# %%
df['is_in_stock'].value_counts() # insights= Nearly all books are available.
# Out:
# is_in_stock
# Yes    400
# Name: count, dtype: int64

# %% [markdown]
# ### Lets Start Visualization

# %% [markdown]
# ##### 1.What is the overall pricing pattern of books?(PRICE DISTRIBUTION)
# - Shows market pricing

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.hist(df['price_gbp'], bins=20)
plt.title("Distribution of Book Prices")
plt.xlabel("Price (GBP)")
plt.ylabel("Number of Books")
plt.show()

# %% [markdown]
# - Most books are priced between £20 and £50, with very few extreme prices.

# %% [markdown]
# ##### 2.What is the quality distribution of books(RATING DISTRIBUTION)
# - Shows customer sentiment
# - Simple categorical analysis
# - Clean insight

# %%
plt.figure()
df['rating_numeric'].value_counts().sort_index().plot(kind='bar')
plt.title("Distribution of Book Ratings")
plt.xlabel("Rating")
plt.ylabel("Number of Books")
plt.show()

# %% [markdown]
# - Most books are rated 3 and 4 stars, indicating generally positive quality

# %% [markdown]
# ##### 3.Do higher-rated books cost more(AVERAGE PRICE BY RATING)
# - Business relationship analysis

# %%
plt.figure()
df.groupby('rating_numeric')['price_gbp'].mean().plot(kind='bar')
plt.title("Average Book Price by Rating")
plt.xlabel("Rating")
plt.ylabel("Average Price (GBP)")
plt.show()

# %% [markdown]
# - Higher-rated books tend to have slightly higher average prices, suggesting perceived quality may influence pricing

# %% [markdown]
# ##### 4.Is price consistent within the same rating? (PRICE VARIATION BY RATING)

# %%
plt.figure()
df.boxplot(column='price_gbp', by='rating_numeric')
plt.title("Price Distribution by Rating")
plt.suptitle("")  # removes default subtitle
plt.xlabel("Rating")
plt.ylabel("Price (GBP)")
plt.show()

# %% [markdown]
# - Even within the same rating, prices vary significantly, showing rating alone does not fully determine price.

# %% [markdown]
# Summary :
# - I scraped 400+ books using Python and BeautifulSoup, cleaned the data, and performed EDA.
# I analyzed price distribution, rating trends, and the relationship between ratings and pricing.
# The analysis shows most books are mid-priced, ratings are generally positive, and higher-rated books tend to be slightly more expensive, though price variation exists within ratings

# %%
#try adavnced one

# %% [markdown]
# - Price vs Rating Relationship
# ##### 5.Is there a clear relationship between book price and rating?

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.scatter(df['rating_numeric'], df['price_gbp'])
plt.title("Relationship Between Book Rating and Price")
plt.xlabel("Rating")
plt.ylabel("Price (GBP)")
plt.show()

# %% [markdown]
# - The scatter plot shows no strict linear relationship, but higher ratings tend to cluster around mid-to-high price ranges, indicating rating alone does not determine price

# %% [markdown]
# - Price Variability Within Same Rating (Market Uncertainty)
# ##### 6.For the same rating, how much does price vary?

# %%
plt.figure()
df.boxplot(column='price_gbp', by='rating_numeric')
plt.title("Price Variability Within Each Rating")
plt.suptitle("")
plt.xlabel("Rating")
plt.ylabel("Price (GBP)")
plt.show()

# %% [markdown]
# - The wide spread in prices within the same rating shows that factors beyond rating—such as author reputation or demand—likely influence pricing

# %% [markdown]
# ##### 7.Which Rating Category Has the Most Expensive Books on Average AND Consistently?

# %%
rating_stats = df.groupby('rating_numeric')['price_gbp'].agg(['mean', 'std'])
rating_stats #calculate mean and std =  mean → average price, std → price fluctuation (risk / inconsistency)
# Out:
#                      mean        std
# rating_numeric
# 1               35.502045  14.166526
# 2               33.605488  13.888323
# 3               34.727625  14.771268
# 4               36.652603  15.085338
# 5               34.418701  14.989869

# %%
plt.figure()
plt.plot(rating_stats.index, rating_stats['mean'], label='Average Price')
plt.plot(rating_stats.index, rating_stats['std'], label='Price Variability')
plt.title("Average Price vs Price Variability by Rating")
plt.xlabel("Rating")
plt.ylabel("GBP")
plt.legend()
plt.show()

# %% [markdown]
# - Higher ratings show higher average prices, but also increased variability, suggesting premium pricing is less consistent in higher-rated categories

# %% [markdown]
# Power summery :
# - Beyond basic EDA, I analyzed price–rating relationships, price variability within ratings, and stability of pricing across categories. The analysis shows that while higher ratings often command higher prices, pricing remains inconsistent, indicating other market factors at play

# %%
df.to_excel("Books_to_scrape_analysis.xlsx", index=False)

# %% [markdown]
# - I scraped and analyzed data in Python and exported the final dataset to Excel for sharing
